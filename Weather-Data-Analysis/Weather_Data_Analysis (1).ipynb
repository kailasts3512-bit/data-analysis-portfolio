# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("weather_data_analysis_dataset.csv")

df.head()
# Out:
#          Date  Temperature_C  Humidity_%  Wind_Speed_km_h  Rainfall_mm  \
# 0  2024-01-01           36.8          59               14         17.1
# 1  2024-01-02           30.0          47               24          5.8
# 2  2024-01-03           32.9          48               12         17.2
# 3  2024-01-04           39.2          53               26          4.3
# 4  2024-01-05           37.3          45               10          9.5
#
#   Weather_Condition
# 0            Stormy
# 1             Sunny
# 2             Sunny
# 3            Cloudy
# 4            Cloudy

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               180 non-null    object
#  1   Temperature_C      180 non-null    float64
#  2   Humidity_%         180 non-null    int64
#  3   Wind_Speed_km_h    180 non-null    int64
#  4   Rainfall_mm        180 non-null    float64
#  5   Weather_Condition  180 non-null    object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 8.6+ KB

# %%
df.isnull().sum()
# Out:
# Date                 0
# Temperature_C        0
# Humidity_%           0
# Wind_Speed_km_h      0
# Rainfall_mm          0
# Weather_Condition    0
# dtype: int64

# %%
df.describe()
# Out:
#        Temperature_C  Humidity_%  Wind_Speed_km_h  Rainfall_mm
# count     180.000000  180.000000       180.000000   180.000000
# mean       28.463889   66.655556        19.555556     7.808889
# std         5.047271   16.514196         8.899954     5.343856
# min        15.200000   40.000000         5.000000     0.000000
# 25%        24.600000   50.750000        11.000000     3.475000
# 50%        28.350000   67.000000        19.000000     6.850000
# 75%        32.225000   81.250000        27.250000    11.050000
# max        39.900000   94.000000        34.000000    21.700000

# %%
avg_temp = df["Temperature_C"].mean()

print("Average Temperature:", avg_temp)
# Out:
# Average Temperature: 28.46388888888889

# %%
plt.plot(df["Temperature_C"])
plt.title("Temperature Trend")
plt.xlabel("Days")
plt.ylabel("Temperature (°C)")
plt.show()

# %%
weather = df["Weather_Condition"].value_counts()

weather.plot(kind="bar")
plt.title("Weather Condition Distribution")
plt.xlabel("Weather Type")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(df["Rainfall_mm"])
plt.title("Rainfall Distribution")
plt.xlabel("Rainfall (mm)")
plt.ylabel("Frequency")
plt.show()
